# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('train (2).csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#original_colums_names

# %%
INDEX_COL=0
NAME_COL='Name'
SEX_COL='Sex'
PCLASS_COL='Pclass'
AGE_COL='Age'
SURVIVED_COL='Survived'
#New colums_name
AGE_GROUP_COL='AgeGroup'
#Other
HEAD_ROWS_TO_SHOW=20

# %%
df[:HEAD_ROWS_TO_SHOW]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
# new_df=df. dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df[SEX_COL].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[PCLASS_COL].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[PCLASS_COL].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
df[AGE_COL].mean()
# Out:
# 29.69911764705882

# %%
df[AGE_COL].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[AGE_COL].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df[AGE_GROUP_COL]=DF[AGE_COL].map(lambda age: int(age//10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8340\3309407834.py in <module>
# ----> 1 df[AGE_GROUP_COL]=DF[AGE_COL].map(lambda age: int(age//10))
#
# NameError: name 'DF' is not defined

# %%
df[AGE_GROUP_COL]=df[AGE_COL]

# %%
df[AGE_GROUP_COL].fillna(-1,inplace=True)

# %%
df[AGE_GROUP_COL]=df[AGE_GROUP_COL].map(lambda age: int(age//10)+1)

# %%
df[:HEAD_ROWS_TO_SHOW]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked  AgeGroup
# 0       0         A/5 21171   7.2500   NaN        S         3
# 1       0          PC 17599  71.2833   C85        C         4
# 2       0  STON/O2. 3101282   7.9250   NaN        S         3
# 3       0            113803  53.1000  C123        S         4
# 4       0            373450   8.0500   NaN        S         4
# 5       0            330877   8.4583   NaN        Q         0
# 6       0             17463  51.8625   E46        S         6
# 7       1            349909  21.0750   NaN        S         1
# 8       2            347742  11.1333   NaN        S         3
# 9       0            237736  30.0708   NaN        C         2
# 10      1           PP 9549  16.7000    G6        S         1
# 11      0            113783  26.5500  C103        S         6
# 12      0         A/5. 2151   8.0500   NaN        S         3
# 13      5            347082  31.2750   NaN        S         4
# 14      0            350406   7.8542   NaN        S         2
# 15      0            248706  16.0000   NaN        S         6
# 16      1            382652  29.1250   NaN        Q         1
# 17      0            244373  13.0000   NaN        S         0
# 18      0            345763  18.0000   NaN        S         4
# 19      0              2649   7.2250   NaN        C         0

# %%
df[AGE_GROUP_COL].value_counts()
# Out:
# 3    220
# 0    177
# 4    167
# 2    102
# 5     89
# 1     62
# 6     48
# 7     19
# 8      6
# 9      1
# Name: AgeGroup, dtype: int64

# %%
df[AGE_GROUP_COL].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='AgeGroup'>

# %%
df[[AGE_GROUP_COL,SURVIVED_COL]][:HEAD_ROWS_TO_SHOW]
# Out:
#     AgeGroup  Survived
# 0          3         0
# 1          4         1
# 2          3         1
# 3          4         1
# 4          4         0
# 5          0         0
# 6          6         0
# 7          1         0
# 8          3         1
# 9          2         1
# 10         1         1
# 11         6         1
# 12         3         0
# 13         4         0
# 14         2         0
# 15         6         1
# 16         1         0
# 17         0         1
# 18         4         0
# 19         0         1

# %%
age_by_survived=df.groupby([AGE_GROUP_COL,SURVIVED_COL])

# %%
age_by_survived

# %%
age_by_survived.size()
# Out:
# AgeGroup  Survived
# 0         0           125
#           1            52
# 1         0            24
#           1            38
# 2         0            61
#           1            41
# 3         0           143
#           1            77
# 4         0            94
#           1            73
# 5         0            55
#           1            34
# 6         0            28
#           1            20
# 7         0            13
#           1             6
# 8         0             6
# 9         1             1
# dtype: int64

# %%
age_by_survived=age_by_survived.size().unstack()

# %%
age_by_survived
# Out:
# Survived      0     1
# AgeGroup
# 0         125.0  52.0
# 1          24.0  38.0
# 2          61.0  41.0
# 3         143.0  77.0
# 4          94.0  73.0
# 5          55.0  34.0
# 6          28.0  20.0
# 7          13.0   6.0
# 8           6.0   NaN
# 9           NaN   1.0

# %%
age_by_survived.fillna(0).plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='AgeGroup'>

# %%
age_by_survived_whithout_na = age_by_survived[1:].fillna(0)
age_by_survived_whithout_na
# Out:
# Survived      0     1
# AgeGroup
# 1          24.0  38.0
# 2          61.0  41.0
# 3         143.0  77.0
# 4          94.0  73.0
# 5          55.0  34.0
# 6          28.0  20.0
# 7          13.0   6.0
# 8           6.0   0.0
# 9           0.0   1.0

# %%
age_by_survived_whithout_na.plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='AgeGroup'>

# %%
def map_to_persent(r):
    return [float(v)/sum(r) for v in r]

# %%
age_by_survived_whithout_na.apply(map_to_persent)
# Out:
# Survived         0         1
# AgeGroup
# 1         0.056604  0.131034
# 2         0.143868  0.141379
# 3         0.337264  0.265517
# 4         0.221698  0.251724
# 5         0.129717  0.117241
# 6         0.066038  0.068966
# 7         0.030660  0.020690
# 8         0.014151  0.000000
# 9         0.000000  0.003448

# %%
age_by_survived_whithout_na.apply(map_to_persent).plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='AgeGroup'>

# %%
df.groupby([SEX_COL, SURVIVED_COL]).size().unstack().fillna(0).apply(map_to_persent).plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
df.groupby([PCLASS_COL, SURVIVED_COL]).size().unstack().fillna(0).apply(map_to_persent).plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='Pclass'>
